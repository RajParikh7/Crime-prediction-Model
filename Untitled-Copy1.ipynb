# %%
import pandas as pd
from datetime import datetime

# %%
df=pd.read_csv('Crimes_-_2001_to_present.csv')

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
df=df.rename_axis({'Date':'DateTime'},axis="columns")

# %%
df[['District','Community Area']]
# Out:
#          District  Community Area
# 0             4.0            45.0
# 1            10.0            30.0
# 2            12.0            23.0
# 3            22.0            73.0
# 4             8.0            70.0
# 5             3.0            42.0
# 6             2.0            38.0
# 7             1.0            32.0
# 8             7.0            69.0
# 9             5.0            53.0
# 10            8.0            65.0
# 11           22.0            75.0
# 12           18.0             8.0
# 13           10.0            29.0
# 14            2.0            39.0
# 15           10.0            30.0
# 16            1.0            32.0
# 17           22.0            73.0
# 18           24.0             2.0
# 19           14.0            22.0
# 20           16.0            10.0
# 21            1.0            32.0
# 22            6.0            44.0
# 23           17.0            13.0
# 24            3.0            42.0
# 25           22.0            71.0
# ...

# %%
df["DateTime"] = df["DateTime"].apply(lambda x:datetime.strptime(x,"%m/%d/%Y %I:%M:%S %p"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-203b2a9de47b> in <module>()
# ----> 1 df["DateTime"] = df["DateTime"].apply(lambda x:datetime.strptime(x,"%m/%d/%Y %I:%M:%S %p"))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
# ...

# %%
df['Date']=[d.date() for d in df['DateTime']]
df['Time']=[d.time() for d in df['DateTime']]

# %%
df['Hour']=df['DateTime'].dt.hour

# %%
df['DateTime'].rename_axis('Date',axis=1)
# Out:
# Date              DateTime    DateTime
# 0      2011-09-30 04:00:00  2011-09-30
# 1      2011-09-02 23:45:00  2011-09-02
# 2      2011-09-04 02:45:00  2011-09-04
# 3      2011-09-04 01:00:00  2011-09-04
# 4      2011-09-05 00:56:00  2011-09-05
# 5      2011-09-06 15:00:00  2011-09-06
# 6      2011-09-02 07:30:00  2011-09-02
# 7      2011-09-09 18:00:00  2011-09-09
# 8      2011-09-14 15:40:00  2011-09-14
# 9      2011-09-14 14:30:00  2011-09-14
# 10     2011-09-03 09:15:00  2011-09-03
# 11     2011-09-21 06:15:00  2011-09-21
# 12     2011-09-21 22:15:00  2011-09-21
# 13     2011-09-23 09:45:00  2011-09-23
# 14     2011-09-23 21:35:00  2011-09-23
# 15     2011-09-25 08:50:00  2011-09-25
# 16     2011-09-30 13:00:00  2011-09-30
# 17     2011-09-25 08:45:00  2011-09-25
# 18     2011-09-30 00:01:00  2011-09-30
# 19     2011-09-02 00:01:00  2011-09-02
# 20     2011-09-15 16:11:00  2011-09-15
# 21     2011-09-01 00:00:00  2011-09-01
# 22     2011-09-14 00:01:00  2011-09-14
# ...

# %%
df=df.dropna(axis=0)

# %%
df.to_csv(r'crime_2011_9_Chicago.csv')

# %%
df1=df.groupby(['Community Area','Beat'],as_index=False)['ID'].count()

# %%
for i in range(len(df1)):
    df1.loc[i,'Hour']=chr(ord('A')+df1.loc[i,'Hour'])

# %%
df1
# Out:
#            Date Hour  DateTime
# 0    2011-09-01    A       100
# 1    2011-09-01    B        26
# 2    2011-09-01    C        29
# 3    2011-09-01    D        19
# 4    2011-09-01    E        19
# 5    2011-09-01    F        11
# 6    2011-09-01    G        23
# 7    2011-09-01    H        27
# 8    2011-09-01    I        43
# 9    2011-09-01    J        93
# 10   2011-09-01    K        56
# 11   2011-09-01    L        50
# 12   2011-09-01    M        70
# 13   2011-09-01    N        59
# 14   2011-09-01    O        42
# 15   2011-09-01    P        54
# 16   2011-09-01    Q        63
# 17   2011-09-01    R        49
# 18   2011-09-01    S        65
# 19   2011-09-01    T        59
# 20   2011-09-01    U        49
# 21   2011-09-01    V        63
# 22   2011-09-01    W        57
# 23   2011-09-01    X        49
# 24   2011-09-02    A        54
# 25   2011-09-02    B        36
# 26   2011-09-02    C        38
# 27   2011-09-02    D        18
# 28   2011-09-02    E        11
# ...

# %%
df2=df1.groupby(['Community Area'],as_index=False)['Beat'].count()

# %%
df2.to_csv('police_station.csv')

# %%
df['Date']=df['Date'].apply(lambda x:datetime.strptime(x,"%Y-%m-%d"))

# %%
df['Date'].dt.day
# Out:
# 0         4
# 1         4
# 2         5
# 3         6
# 4         9
# 5        14
# 6        14
# 7         3
# 8        21
# 9        21
# 10       23
# 11       23
# 12       30
# 13       25
# 14        9
# 15        9
# 16        1
# 17        1
# 18        1
# 19        1
# 20        1
# 21        1
# 22        1
# 23        1
# 24        1
# 25        1
# 26        1
# 27        1
# 28        1
# 29        1
#          ..
# 29785     8
# 29786    11
# 29787    11
# 29788    12
# 29789    13
# 29790    13
# 29791    13
# 29792    14
# 29793    14
# 29794    15
# 29795    15
# 29796    17
# 29797    18
# 29798    18
# 29799    18
# 29800    18
# 29801    19
# 29802    19
# 29803    22
# 29804    22
# 29805    23
# 29806    26
# 29807    26
# 29808    26
# 29809    28
# 29810    10
# 29811     7
# 29812     3
# 29813    24
# 29814    13
# Name: Date, Length: 29815, dtype: int64
