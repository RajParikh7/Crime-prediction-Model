# %%
import pandas as pd

# %%
pd2=pd.read_csv('train.csv')

# %%
pd2
# Out:
#        Unnamed: 0  Year  month       time  Community  crime_count  \
# 0               0  2010      1  afternoon         44          214
# 1               1  2010      1  afternoon         45           47
# 2               2  2010      1  afternoon         46          191
# 3               3  2010      1  afternoon         47           13
# 4               4  2010      1  afternoon         48           51
# 5               5  2010      1  afternoon         49          273
# 6               6  2010      1  afternoon          5           50
# 7               7  2010      1  afternoon         50           46
# 8               8  2010      1  afternoon         51           49
# 9               9  2010      1  afternoon         52           59
# 10             10  2010      1  afternoon         53          129
# 11             11  2010      1  afternoon         54           34
# 12             12  2010      1  afternoon         55           13
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
enc = OneHotEncoder(handle_unknown='ignore')
le = LabelEncoder()

# %%
x=pd2['PERCENT OF HOUSING CROWDED']
y=pd3['Count']
x=np.reshape(x,(-1,1))
y=np.reshape(y,(-1,1))
len(x)
# Out:
# C:\Users\rajpa\AppData\Roaming\Python\Python36\site-packages\numpy\core\fromnumeric.py:51: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# 77

# %%
import numpy as np
x1=pd2['Year'].astype('int')
x2=pd2['month'].astype('int')
x3=pd2['time']
x4=pd2['Street_lights'].astype('int')
x5=pd2['Sanitation_request'].astype('int')
x6=pd2['building_abandon'].astype('int')
x3=le.fit_transform(x3)
x3=np.reshape(x3,(-1,1))
x3=enc.fit_transform(x3)
x7=[x3[i,0] for i in range(x3.shape[0])]
x8=[x3[i,1] for i in range(x3.shape[0])]
x9=[x3[i,2] for i in range(x3.shape[0])]
x10=[x3[i,3] for i in range(x3.shape[0])]
x11=pd2['Black'].astype('int')

y=pd2['crime_count'].astype('int')
x=[x1,x2,x4,x5,x6,x7,x8,x9,x10]
x=np.reshape(x,(-1,9))
y=np.reshape(y,(-1,1))
from sklearn.linear_model import LinearRegression
reg=LinearRegression().fit(x,y)
# Out:
# C:\Users\rajpa\AppData\Roaming\Python\Python36\site-packages\numpy\core\fromnumeric.py:51: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
reg.score(x,y)
# Out:
# 0.0097335512362684

# %%
from sklearn.ensemble import GradientBoostingRegressor as GBR
reg=GBR(n_estimators=1000, learning_rate=0.1,max_depth=9).fit(x,y)
# Out:
# C:\Users\rajpa\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
result=reg.predict(x)

# %%
mse=0
for i in range(len(result)):
    mse=mse+(result[i]-y[i])**2
mse=mse/i
mse**0.5
# Out:
# array([64.00445536])

# %%
mse=sum((result-y)**2)/len(result)
mse**0.5
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-198-21084d405068> in <module>()
# ----> 1 mse=sum((result-y)**2)/len(result)
#
# MemoryError:

# %%
y==min(y)
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import r2_score
r2_score(result,y)
# Out:
# -0.9413802881328444

# %%
f=open('results.csv','w')
for i in range(len(result)):
    f.write(str(y[i][0]))
    f.write(',')
    f.write(str(result[i][0]))
    f.write(',')
    f.write('\n')
f.close()
