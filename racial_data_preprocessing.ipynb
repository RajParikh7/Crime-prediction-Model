# %%
f=open('Final Tables through 2016 - Race & Ethnicity.csv')
f1=f.readlines()
f2=open('Race_count_2016_1.csv','w')
line1=""
f2.write('Community,Total,asian,Black,hispanic,white,other \n')
for i in range(1,len(f1)):
    line=f1[i]
    line=line.strip()
    if line==',':
        line1=line1+"\n"
        f2.write(line1)
        line1=""
    elif line1=="":
        line1=line.split(' ')[0]
    else:
        print(line.split(','))
        line1=line1+','+line.split(',')[1]
# Out:
# ['Total', '55500']
# ['Asian', '3205']
# ['Black or African-American', '14455']
# ['Persons of Spanish Language*', '12383']
# ['White', '23604']
# ['Other', '1853']
# ['Total', '73723']
# ['Asian', '16641']
# ['Black or African-American', '8936']
# ['Persons of Spanish Language*', '13366']
# ['White', '31806']
# ['Other', '2974']
# ['Total', '56296']
# ['Asian', '5773']
# ['Black or African-American', '10970']
# ['Persons of Spanish Language*', '7468']
# ['White', '30456']
# ['Other', '1629']
# ['Total', '41483']
# ['Asian', '4608']
# ['Black or African-American', '1394']
# ['Persons of Spanish Language*', '7284']
# ['White', '26554']
# ['Other', '1643']
# ['Total', '34942']
# ['Asian', '1563']
# ['Black or African-American', '713']
# ['Persons of Spanish Language*', '4378']
# ['White', '26996']
# ['Other', '1292']
# ['Total', '99876']
# ['Asian', '6735']
# ['Black or African-American', '3320']
# ['Persons of Spanish Language*', '8099']
# ['White', '78859']
# ['Other', '2863']
# ...

# %%
f2.write(line1)
f.close()
f2.close()

# %%
line1
# Out:
# '77.,55430,6430,7592,9081,30615,1712'
