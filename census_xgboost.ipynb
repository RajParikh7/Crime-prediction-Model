# %%
import pandas as pd

# %%
pd2=pd.read_csv('Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv',sep='\t')

# %%
pd2=pd2[pd2['year']==2011]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-5616ca6030e3> in <module>()
# ----> 1 pd2=pd2[pd2['year']==2011]
#
# ...

# %%
pd1=pd.read_csv('Community_year.csv')

# %%
pd3=pd1[pd1['Year']==2011]

# %%
pd2
# Out:
#     Community Area Number     COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                       1             Rogers Park                         7.7
# 1                       2              West Ridge                         7.8
# 2                       3                  Uptown                         3.8
# 3                       4          Lincoln Square                         3.4
# 4                       5            North Center                         0.3
# 5                       6               Lake View                         1.1
# 6                       7            Lincoln Park                         0.8
# 7                       8         Near North Side                         1.9
# 8                       9             Edison Park                         1.1
# 9                      10            Norwood Park                         2.0
# 10                     11          Jefferson Park                         2.7
# ...

# %%
x=pd2['PERCENT OF HOUSING CROWDED']
y=pd3['Count']
x=np.reshape(x,(-1,1))
y=np.reshape(y,(-1,1))
len(x)
# Out:
# C:\Users\rajpa\AppData\Roaming\Python\Python36\site-packages\numpy\core\fromnumeric.py:51: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# 77

# %%
import numpy as np
x1=pd2['PERCENT OF HOUSING CROWDED'].astype('int')
x2=pd2['PERCENT HOUSEHOLDS BELOW POVERTY'].astype('int')
x3=pd2['PERCENT AGED 16+ UNEMPLOYED'].astype('int')
x4=pd2['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA'].astype('int')
y=pd3['Count'].astype('int')
x=[x1,x2,x3]
x=np.reshape(x,(-1,3))
y=np.reshape(y,(-1,1))
from sklearn.linear_model import LinearRegression
reg=LinearRegression().fit(x,y)
# Out:
# C:\Users\rajpa\AppData\Roaming\Python\Python36\site-packages\numpy\core\fromnumeric.py:51: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
reg.score(x,y)
# Out:
# 0.02197175089632475

# %%
from sklearn.ensemble import GradientBoostingRegressor as GBR
reg=GBR(n_estimators=1, learning_rate=0.01).fit(x,y)
# Out:
# C:\Users\rajpa\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
result=reg.predict(x)

# %%
mse=sum(result**2)/len(result)

# %%
mse**0.5
# Out:
# array([4592.20063238])

# %%
from sklearn.metrics import r2_score
r2_score(result,y)
# Out:
# -43.51298641235143
